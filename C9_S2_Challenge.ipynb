# %% [markdown]
# # Linear Regression (LR)

# %% [markdown]
# # Challenge

# %%
# Importing Required Liabraries

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sb
from sklearn import preprocessing
from sklearn.model_selection import train_test_split
from sklearn import linear_model
from sklearn.linear_model import LinearRegression
import sklearn.metrics as me
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error

# %% [markdown]
# ### Task 1.1 & 1.2 : Generate random regression problem. Generate a dataset with make_regression using noise=4, bias=100, one input variable and 100 sample points.

# %%
# Generating random dataset with make_regression problem

from sklearn.datasets import make_regression
X=make_regression(n_samples=100,n_features=1,n_targets=1,bias=100,noise=4)

# %%
# Reading the Data

print(X)
X
# Out:
# (array([[-0.04241571],
#        [ 1.17272101],
#        [ 1.06028109],
#        [-0.45528428],
#        [-0.43959771],
#        [ 0.85172025],
#        [-0.05787521],
#        [-1.75849164],
#        [-0.18130144],
#        [-0.7542684 ],
#        [ 0.2515426 ],
#        [ 0.09980031],
#        [-0.35015797],
#        [-0.15570151],
#        [ 1.28021963],
#        [ 0.58146177],
#        [ 0.12104757],
#        [-0.12142742],
#        [-0.25403507],
#        [ 0.15967373],
#        [-0.24328916],
#        [-3.0548778 ],
#        [ 0.27274801],
#        [ 0.41165931],
#        [ 0.78649115],
#        [ 2.06806444],
#        [-0.38786511],
#        [-0.78946697],
#        [-0.59454681],
#        [ 1.52019797],
#        [-1.72128476],
#        [-0.34667491],
#        [-0.25958404],
#        [-0.83247112],
#        [-2.13387127],
#        [-1.01054262],
#        [ 0.35611407],
#        [-1.1686212 ],
#        [ 0.66767078],
#        [-0.04124867],
#        [ 1.72387078],
# ...

# %%
X
# Out:
# (array([[-0.04241571],
#         [ 1.17272101],
#         [ 1.06028109],
#         [-0.45528428],
#         [-0.43959771],
#         [ 0.85172025],
#         [-0.05787521],
#         [-1.75849164],
#         [-0.18130144],
#         [-0.7542684 ],
#         [ 0.2515426 ],
#         [ 0.09980031],
#         [-0.35015797],
#         [-0.15570151],
#         [ 1.28021963],
#         [ 0.58146177],
#         [ 0.12104757],
#         [-0.12142742],
#         [-0.25403507],
#         [ 0.15967373],
#         [-0.24328916],
#         [-3.0548778 ],
#         [ 0.27274801],
#         [ 0.41165931],
#         [ 0.78649115],
#         [ 2.06806444],
#         [-0.38786511],
#         [-0.78946697],
#         [-0.59454681],
#         [ 1.52019797],
#         [-1.72128476],
#         [-0.34667491],
#         [-0.25958404],
#         [-0.83247112],
#         [-2.13387127],
#         [-1.01054262],
#         [ 0.35611407],
#         [-1.1686212 ],
#         [ 0.66767078],
#         [-0.04124867],
# ...

# %% [markdown]
# ### Task 1.2 : Visualize the toy dataset with scatter plot

# %%
#Plotting scatter plot

fig,ax=plt.subplots()
plt.scatter(X,y)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_6756\4263055228.py in <module>
#       2
#       3 fig,ax=plt.subplots()
# ----> 4 plt.scatter(X,y)
#       5 plt.show()
#
# NameError: name 'y' is not defined

# %%
## Inference X and y varies linearly

# %% [markdown]
# ### Task 1.3 Fit the linear regression model to the dataset (line plot) and visualize it with the data

# %%
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.3,random_state=100)  #Data splitting into train and test
LR=LinearRegression().fit(X_train,y_train)       #Fitting data into linear Regression Model
pred_y=LR.predict(X_test)                        # Finding predicted Y values
plt.figure(figsize=(10,8))
fig,ax=plt.subplots()
plt.scatter(X,y)                                 # Plotting scatter plot
plt.plot(X_test.squeeze(),pred_y.squeeze(),color='r')    # Plotting line plot
plt.show()

# %% [markdown]
# ### Task 2.1 : Add some outliers in the data

# %%
print(X.max())
print(X.min())
X_random=np.array([-5.43,-6.28,-9.6,6,8,4])
X_random.reshape(-1,1)

# %%
print(y.max())
print(y.min())
y_random=np.array([-1.02,-0.02,-1.96,200,203,206])
y_random.reshape(-1,1)

# %%
X=np.append(X,X_random,axis=None)
X.shape
