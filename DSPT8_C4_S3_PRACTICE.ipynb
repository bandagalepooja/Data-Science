# %%
import pandas as pd
import numpy as np

# %%
data=pd.read_csv('DS1_C4_S3_Loan_Data_Practice.csv.csv')
data
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0    LP001002    Male      No          0      Graduate            No
# 1    LP001003    Male     Yes          1      Graduate            No
# 2    LP001005    Male     Yes          0      Graduate           Yes
# 3    LP001006    Male     Yes          0  Not Graduate            No
# 4    LP001008    Male      No          0      Graduate            No
# ..        ...     ...     ...        ...           ...           ...
# 609  LP002978  Female      No          0      Graduate            No
# 610  LP002979    Male     Yes         3+      Graduate            No
# 611  LP002983    Male     Yes          1      Graduate            No
# 612  LP002984    Male     Yes          2      Graduate            No
# 613  LP002990  Female      No          0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# ...

# %%
data.columns
# Out:
# Index(['Loan_ID', 'Gender', 'Married', 'Dependents', 'Education',
#        'Self_Employed', 'ApplicantIncome', 'CoapplicantIncome', 'LoanAmount',
#        'Loan_Amount_Term', 'Credit_History', 'Property_Area', 'Loan_Status'],
#       dtype='object')

# %% [markdown]
# Task 1 : Find number of male customers who are graduate and have the loan status as 'Yes'. Display the information

# %%
x=data[(data['Gender']=='Male')&(data['Education']=='Graduate')&(data['Loan_Status']=='Y')]
x
# Out:
#       Loan_ID Gender Married Dependents Education Self_Employed  \
# 0    LP001002   Male      No          0  Graduate            No
# 2    LP001005   Male     Yes          0  Graduate           Yes
# 4    LP001008   Male      No          0  Graduate            No
# 5    LP001011   Male     Yes          2  Graduate           Yes
# 8    LP001018   Male     Yes          2  Graduate            No
# ..        ...    ...     ...        ...       ...           ...
# 606  LP002961   Male     Yes          1  Graduate            No
# 608  LP002974   Male     Yes          0  Graduate            No
# 610  LP002979   Male     Yes         3+  Graduate            No
# 611  LP002983   Male     Yes          1  Graduate            No
# 612  LP002984   Male     Yes          2  Graduate            No
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0               5849                0.0         146               360
# ...

# %%
print('No. of customers = ',x.shape[0])
# Out:
# No. of customers =  279

# %% [markdown]
# Task 2: Dispaly records of female customers who are self employed and have an income greater than $4000

# %%
y=data[(data['Gender']=='Female') & (data['Self_Employed']=='Yes') & (data['ApplicantIncome']>4000)]
y
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 54   LP001186  Female     Yes          1      Graduate           Yes
# 113  LP001392  Female      No          1      Graduate           Yes
# 353  LP002142  Female     Yes          0      Graduate           Yes
# 370  LP002194  Female      No          0      Graduate           Yes
# 404  LP002301  Female      No          0      Graduate           Yes
# 430  LP002377  Female      No          1      Graduate           Yes
# 439  LP002407  Female     Yes          0  Not Graduate           Yes
# 463  LP002489  Female      No          1  Not Graduate           Yes
# 493  LP002582  Female      No          0  Not Graduate           Yes
# 534  LP002731  Female      No          0  Not Graduate           Yes
# 561  LP002813  Female     Yes          1      Graduate           Yes
# 613  LP002990  Female      No          0      Graduate           Yes
#
# ...

# %% [markdown]
# Task 3 : Display details of customers who have more than 3 dependents, have 'Rural' property area and loan status as 'Approved'

# %%
z=data[(data['Dependents']=='3+')&(data['Property_Area']=='Rural')&(data['Loan_Status']=='Y')]
z
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 126  LP001448    Male     Yes         3+      Graduate            No
# 213  LP001715    Male     Yes         3+  Not Graduate           Yes
# 255  LP001846  Female      No         3+      Graduate            No
# 324  LP002065    Male     Yes         3+      Graduate            No
# 352  LP002141    Male     Yes         3+      Graduate            No
# 376  LP002219    Male     Yes         3+      Graduate            No
# 390  LP002255    Male      No         3+      Graduate            No
# 391  LP002262    Male     Yes         3+      Graduate            No
# 481  LP002536    Male     Yes         3+  Not Graduate            No
# 515  LP002659    Male     Yes         3+      Graduate            No
# 522  LP002692    Male     Yes         3+      Graduate           Yes
# 539  LP002740    Male     Yes         3+      Graduate            No
# 610  LP002979    Male     Yes         3+      Graduate            No
#
# ...

# %% [markdown]
# Task 4 : Find average income of the customers for whom loan worth of $290 or more was approved.

# %%
avg=data[(data['LoanAmount']>290) & (data['Loan_Status']=='Y')]['ApplicantIncome'].mean()
print('Average Income',round(avg,2))
# Out:
# Average Income 18641.7

# %% [markdown]
# Task 5: Display details of customers who are unmarried, self employed & whosse loan got rejected.Also find ow many male and female customers fall into this category.

# %%
a=data[(data['Loan_Status']=='N')&(data['Self_Employed']=='Yes')&(data['Married']=='No')]
a
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 32   LP001097    Male      No          1      Graduate           Yes
# 95   LP001326    Male      No          0      Graduate           Yes
# 107  LP001370    Male      No          0  Not Graduate           Yes
# 199  LP001673    Male      No          0      Graduate           Yes
# 245  LP001813    Male      No          0      Graduate           Yes
# 254  LP001844    Male      No          0      Graduate           Yes
# 280  LP001910    Male      No          1  Not Graduate           Yes
# 286  LP001925  Female      No          0      Graduate           Yes
# 404  LP002301  Female      No          0      Graduate           Yes
# 410  LP002318  Female      No          1  Not Graduate           Yes
# 438  LP002403    Male      No          0      Graduate           Yes
# 449  LP002444    Male      No          1  Not Graduate           Yes
# 600  LP002949  Female      No         3+      Graduate           Yes
# ...

# %%
a['Gender'].value_counts()
# Out:
# Male      9
# Female    5
# Name: Gender, dtype: int64

# %% [markdown]
# Task 6 : Find applicantes income by area

# %%
data['Property_Area'].value_counts()
# Out:
# Semiurban    233
# Urban        202
# Rural        179
# Name: Property_Area, dtype: int64

# %%
data[data['Property_Area']=='Semiurban'][['ApplicantIncome','Property_Area']]
# Out:
#      ApplicantIncome Property_Area
# 7               3036     Semiurban
# 9              12841     Semiurban
# 22              2600     Semiurban
# 24              3717     Semiurban
# 25              9560     Semiurban
# ..               ...           ...
# 592             9357     Semiurban
# 597             2987     Semiurban
# 604            12000     Semiurban
# 606             3400     Semiurban
# 613             4583     Semiurban
#
# [233 rows x 2 columns]

# %%
data[data['Property_Area']=='Urban'][['ApplicantIncome','Property_Area']]
# Out:
#      ApplicantIncome Property_Area
# 0               5849         Urban
# 2               3000         Urban
# 3               2583         Urban
# 4               6000         Urban
# 5               5417         Urban
# ..               ...           ...
# 600              416         Urban
# 602             5703         Urban
# 605             2400         Urban
# 611             8072         Urban
# 612             7583         Urban
#
# [202 rows x 2 columns]

# %%
data[data['Property_Area']=='Rural'][['ApplicantIncome','Property_Area']]
# Out:
#      ApplicantIncome Property_Area
# 1               4583         Rural
# 13              1853         Rural
# 18              4887         Rural
# 23              3365         Rural
# 32              4692         Rural
# ..               ...           ...
# 603             3676         Rural
# 607             3987         Rural
# 608             3232         Rural
# 609             2900         Rural
# 610             4106         Rural
#
# [179 rows x 2 columns]

# %%
data.groupby('Property_Area')['ApplicantIncome'].mean()
# Out:
# Property_Area
# Rural        5554.083799
# Semiurban    5292.261803
# Urban        5398.247525
# Name: ApplicantIncome, dtype: float64

# %% [markdown]
# Task 7 : Find number of married customers whose co-applicants income is less than the avg income of all co-applicants and have their loan approved.

# %%
b=data['CoapplicantIncome'].mean()
b
# Out:
# 1621.245798027101

# %%
data[(data['CoapplicantIncome']<b) & (data['Loan_Status']=='Y') & (data['Married']=='Yes')].shape[0]
# Out:
# 147

# %% [markdown]
# Task 8 : Find number of customers who are graduates & have an income range between $10256 & $150000.

# %%
c=data[(data['Education']=='Graduate') & (data['ApplicantIncome'].between(10256,150000,inclusive = True))].shape[0]
print('No of customers : ',c)
# Out:
# No of customers :  48
# C:\Users\Admin\AppData\Local\Temp\ipykernel_4940\3124995724.py:1: FutureWarning: Boolean inputs to the `inclusive` argument are deprecated in favour of `both` or `neither`.
#   c=data[(data['Education']=='Graduate') & (data['ApplicantIncome'].between(10256,150000,inclusive = True))].shape[0]
